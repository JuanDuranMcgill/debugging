# %%
import os
import xml.etree.ElementTree as ET
import pandas as pd
import numpy as np
import glob
import xmltodict
from IPython.display import display, HTML


# Function to drop columns with all same values or all NaN values
def drop_constant_columns(df):
    # Drop columns with all NaN values
    df = df.dropna(axis=1, how='all')

    # Find columns where all values are the same (including columns with a single unique non-NaN value)
    nunique = df.apply(pd.Series.nunique, dropna=False)
    cols_to_drop = nunique[nunique <= 1].index

    # Drop these columns
    df = df.drop(cols_to_drop, axis=1)

    return df

# Display the DataFrame in a scrollable format
def display_scrollable_dataframe(df, max_rows=20):
    display(HTML(df.to_html(max_rows=max_rows, classes='table table-striped table-bordered table-hover')))

# Function to recursively extract tags and values
def extract_tags_and_values(elem, parent_tag="", tag_count=None):
    if tag_count is None:
        tag_count = {}

    data = {}
    for child in elem:
        # Get the base tag without any namespaces
        base_tag = child.tag.split('}')[-1]

        # If this tag has a sequence attribute, append it to the tag
        sequence = child.attrib.get('sequence')

        # Construct full tag name, including parent if necessary
        if parent_tag:
            full_tag = f"{parent_tag}.{base_tag}"
        else:
            full_tag = base_tag

        # Handle repeated tags: append index or sequence to make the tag unique
        if sequence:
            full_tag += f"_seq_{sequence}"
        elif full_tag in tag_count:
            tag_count[full_tag] += 1
            full_tag += f"_{tag_count[full_tag]}"
        else:
            tag_count[full_tag] = 1

        # If the child has text and it's not just whitespace, store the value
        if child.text and child.text.strip():
            data[full_tag] = child.text.strip()

        # Recursively call the function to process the child elements
        data.update(extract_tags_and_values(child, full_tag, tag_count))

    return data

# Function to process all XML files in subfolders and consolidate them into a DataFrame
def process_xml_files(root_folder):
    all_data = []

    # Recursively find all XML files in the root folder and subfolders
    xml_files = glob.glob(os.path.join(root_folder, '**/*.xml'), recursive=True)

    for xml_file in xml_files:
        # Load and parse each XML file
        tree = ET.parse(xml_file)
        root = tree.getroot()

        # Extract the patient data using the extract_tags_and_values function
        patient_data = extract_tags_and_values(root)

        # Add the patient data to the list
        all_data.append(patient_data)

    # Convert the list of dictionaries to a pandas DataFrame
    df = pd.DataFrame(all_data)

    # Optionally: Drop columns that have all NaN values or are constant
    df_cleaned = drop_constant_columns(df)

    return df_cleaned

# Function to extract and organize follow-up columns dynamically
def extract_and_organize_followup(df, prefix="follow_up_seq"):
    # Extract columns that match the follow-up sequence prefix
    follow_up_columns = [col for col in df.columns if prefix in col]
    
    # Extract unique sequence numbers dynamically (e.g., _1, _2, etc.)
    seq_numbers = sorted(set([col.split(f"{prefix}_")[1].split('_')[0] for col in follow_up_columns if f"{prefix}_" in col]))
    
    # Organize columns based on the sequence numbers
    organized_columns = []
    for seq in seq_numbers:
        seq_columns = [col for col in follow_up_columns if f"{prefix}_{seq}" in col]
        organized_columns.extend(seq_columns)
    
    return organized_columns

# Function to extract and organize drug columns, accounting for drug_1 being just 'patient.drugs.drug'
def extract_and_organize_drugs(df, base_prefix="patient.drugs.drug"):
    # Extract all drug-related columns (both drug_1 and drug_x)
    drug_columns = [col for col in df.columns if base_prefix in col]
    
    # Special handling for 'drug_1' columns without a suffix
    drug_1_columns = [col for col in drug_columns if base_prefix + "_" not in col]
    
    # Extract unique drug sequence numbers dynamically, handling possible extra parts in the column names
    drug_seq_numbers = sorted(set([int(col.split(f"{base_prefix}_")[1].split('.')[0])
                                   for col in drug_columns if f"{base_prefix}_" in col]))
    
    # Organize columns based on the sequence numbers
    organized_columns = drug_1_columns  # Start with drug_1 columns
    for seq in drug_seq_numbers:
        seq_columns = [col for col in drug_columns if f"{base_prefix}_{seq}." in col]
        organized_columns.extend(seq_columns)
    
    return organized_columns

# %% [markdown]
# Edition standardizations scripts here

# %%
def map_icd_to_site(icd_code):
    """Maps ICD-10 code to the corresponding AJCC site."""
    
    if icd_code in ['C02.9', 'C04.9', 'C06.9', 'C06.0', 'C03.9', 'C00.9', 'C05.0', 'C03.1', 'C04.0', 'C06.2', 'C02.1', 'C05.9', 'C03.0', 'C02.2']:
        return 'Section 3'
    
    elif icd_code in ['C32.9','C32.1']:
        return 'Section 5'
    
    elif icd_code == 'C14.8':
        return 'Section 9'
    
    elif icd_code in ['C09.9', 'C01', 'C10.9', 'C10.3','C13.9']:
        return 'Section 4'
    
    elif icd_code == 'C41.1':
        return 'Section 27'
    
    else:
        return 'Unknown Site'
    
def map_section_3_6th_to_7th(t_stage_6th, n_stage_6th, m_stage_6th):
    """Maps AJCC 6th edition to 7th edition for Section 3: Lip and Oral Cavity."""
    # T4 lesions have been divided into T4a (moderately advanced local disease) 
    # and T4b (very advanced local disease), leading to the stratification of 
    # Stage IV into Stage IVA, IVB, and IVC.
    if t_stage_6th == 'T4':
        return 'T4a', n_stage_6th, m_stage_6th  # T4 has been split into T4a and T4b
    else:
        return t_stage_6th, n_stage_6th, m_stage_6th


def map_section_4_6th_to_7th(t_stage_6th, n_stage_6th, m_stage_6th, tissue_or_organ):
    """Maps AJCC 6th edition to 7th edition for Section 4 using the provided mappings."""
    
    if tissue_or_organ in ['Oral Tongue', 'Oral Cavity', 'Floor of mouth', 'Tonsil', 'Base of tongue', 'Buccal Mucosa', 
                           'Alveolar Ridge', 'Hard Palate', 'Lip', 'Oropharynx', 'Hypopharynx', 'Larynx']:
        # The conditions here should match your exact categories
        if t_stage_6th == 'T4':
            return 'T4a', n_stage_6th, m_stage_6th  # Modify based on specific stratification
        else:
            return t_stage_6th, n_stage_6th, m_stage_6th
    else:
        return t_stage_6th, n_stage_6th, m_stage_6th

def map_section_5_6th_to_7th(t_stage_6th, n_stage_6th, m_stage_6th):
    """Maps AJCC 6th edition to 7th edition for Section 5: Larynx."""
    # T4 lesions have been divided into T4a (moderately advanced local disease) 
    # and T4b (very advanced local disease), leading to the stratification of 
    # Stage IV into Stage IVA, IVB, and IVC.
    if t_stage_6th == 'T4':
        return 'T4a', n_stage_6th, m_stage_6th  # T4 has been split into T4a and T4b
    else:
        return t_stage_6th, n_stage_6th, m_stage_6th

def map_section_9_6th_to_7th(t_stage_6th, n_stage_6th, m_stage_6th):
    """Maps AJCC 6th edition to 7th edition for Section 9: Mucosal Melanoma of the Head and Neck."""
    # No changes needed for Section 9 as it didn't exist in the 6th edition.
    return t_stage_6th, n_stage_6th, m_stage_6th

def map_section_27_6th_to_7th(t_stage_6th, n_stage_6th, m_stage_6th):
    """Maps AJCC 6th edition to 7th edition for Section 27: Bone (Mandible)."""
    # Stage III is reserved for G3 and G4 grades in the 7th edition.
    return t_stage_6th, n_stage_6th, m_stage_6th


    
def map_ajcc_6th_to_7th(icd_code, t_stage_6th, n_stage_6th, m_stage_6th, tissue_or_organ, grade=None):
    """Maps AJCC 6th edition to 7th edition based on the section derived from the ICD-10 code."""
    section = map_icd_to_site(icd_code)
    
    if section == 'Section 3':
        return map_section_3_6th_to_7th(t_stage_6th, n_stage_6th, m_stage_6th)
    elif section == 'Section 4':
        return map_section_4_6th_to_7th(t_stage_6th, n_stage_6th, m_stage_6th, tissue_or_organ)
    elif section == 'Section 5':
        return map_section_5_6th_to_7th(t_stage_6th, n_stage_6th, m_stage_6th)
    elif section == 'Section 9':
        return map_section_9_6th_to_7th(t_stage_6th, n_stage_6th, m_stage_6th)
    elif section == 'Section 27':
        return map_section_27_6th_to_7th(t_stage_6th, n_stage_6th, m_stage_6th)
    else:
        return 'Unknown Section', t_stage_6th, n_stage_6th, m_stage_6th

def map_section_3_5th_to_6th(t_stage_5th, n_stage_5th, m_stage_5th):
    """Maps AJCC 5th edition to 6th edition for Section 3: Lip and Oral Cavity."""
    # T4 lesions have been divided into T4a (resectable) and T4b (unresectable), 
    # leading to the division of Stage IV into Stage IVA, IVB, and IVC.
    if t_stage_5th == 'T4':
        return 'T4a', n_stage_5th, m_stage_5th  # Assuming resectable; adjust if needed
    else:
        return t_stage_5th, n_stage_5th, m_stage_5th

def map_section_4_5th_to_6th(t_stage_5th, n_stage_5th, m_stage_5th, tissue_or_organ):
    """Maps AJCC 5th edition to 6th edition for Section 4: Pharynx, considering the specific subregions."""

    # For oropharynx and hypopharynx subdivisions:
    # T4 lesions are divided into T4a and T4b in the 6th edition.

    if tissue_or_organ in ['Oral Tongue', 'Oral Cavity', 'Floor of mouth', 'Tonsil', 'Base of tongue',
                           'Buccal Mucosa', 'Alveolar Ridge', 'Hard Palate', 'Lip', 'Oropharynx', 'Hypopharynx', 'Larynx']:
        if t_stage_5th == 'T4':
            return 'T4a', n_stage_5th, m_stage_5th  # Assuming resectable
        else:
            return t_stage_5th, n_stage_5th, m_stage_5th
    else:
        return t_stage_5th, n_stage_5th, m_stage_5th


def map_section_5_5th_to_6th(t_stage_5th, n_stage_5th, m_stage_5th):
    """Maps AJCC 5th edition to 6th edition for Section 5: Larynx."""
    # T4 lesions have been divided into T4a (resectable) and T4b (unresectable),
    # leading to the division of Stage IV into Stage IVA, IVB, and IVC.
    if t_stage_5th == 'T4':
        return 'T4a', n_stage_5th, m_stage_5th  # Assuming resectable; adjust if needed
    else:
        return t_stage_5th, n_stage_5th, m_stage_5th

def map_section_9_5th_to_6th(t_stage_5th, n_stage_5th, m_stage_5th):
    """Maps AJCC 5th edition to 6th edition for Section 9: Mucosal Melanoma of the Head and Neck."""
    # No changes needed for Section 9 as it did not exist in the 6th edition.
    return t_stage_5th, n_stage_5th, m_stage_5th

def map_section_27_5th_to_6th(t_stage_5th, n_stage_5th, m_stage_5th):
    """Maps AJCC 5th edition to 6th edition for Section 27: Bone (Mandible)."""
    # M1 lesions have been divided into M1a and M1b:
    # - M1a is lung-only metastases (Stage IVA)
    # - M1b is metastases to other distant sites, including lymph nodes (Stage IVB).
    if m_stage_5th == 'M1':
        return t_stage_5th, n_stage_5th, 'M1a'  
    else:
        return t_stage_5th, n_stage_5th, m_stage_5th

def map_ajcc_5th_to_6th(icd_code, t_stage_5th, n_stage_5th, m_stage_5th, tissue_or_organ):
    """Maps AJCC 5th edition to 6th edition based on the section derived from the ICD-10 code."""
    section = map_icd_to_site(icd_code)
    
    if section == 'Section 3':
        return map_section_3_5th_to_6th(t_stage_5th, n_stage_5th, m_stage_5th)
    elif section == 'Section 4':
        return map_section_4_5th_to_6th(t_stage_5th, n_stage_5th, m_stage_5th, tissue_or_organ)
    elif section == 'Section 5':
        return map_section_5_5th_to_6th(t_stage_5th, n_stage_5th, m_stage_5th)
    elif section == 'Section 9':
        return map_section_9_5th_to_6th(t_stage_5th, n_stage_5th, m_stage_5th)
    elif section == 'Section 27':
        return map_section_27_5th_to_6th(t_stage_5th, n_stage_5th, m_stage_5th)
    else:
        return t_stage_5th, n_stage_5th, m_stage_5th

def map_clinical_5th_to_6th(row):
    # Clinical mapping
    clinical_t, clinical_n, clinical_m = map_ajcc_5th_to_6th(
        icd_code=row['patient.icd_10'],
        t_stage_5th=row['patient.stage_event.tnm_categories.clinical_categories.clinical_T'],
        n_stage_5th=row['patient.stage_event.tnm_categories.clinical_categories.clinical_N'],
        m_stage_5th=row['patient.stage_event.tnm_categories.clinical_categories.clinical_M'],
        tissue_or_organ=row['patient.anatomic_neoplasm_subdivision']
    )
    
    return pd.Series({
        'ajcc_clinical_t': clinical_t,
        'ajcc_clinical_n': clinical_n,
        'ajcc_clinical_m': clinical_m

    })

def map_clinical_6th_to_7th(row):
    # Clinical mapping
    clinical_t, clinical_n, clinical_m = map_ajcc_6th_to_7th(
        icd_code=row['patient.icd_10'],
        t_stage_6th=row['patient.stage_event.tnm_categories.clinical_categories.clinical_T'],
        n_stage_6th=row['patient.stage_event.tnm_categories.clinical_categories.clinical_N'],
        m_stage_6th=row['patient.stage_event.tnm_categories.clinical_categories.clinical_M'],
        tissue_or_organ=row['patient.anatomic_neoplasm_subdivision']
    )
    
    return pd.Series({
        'ajcc_clinical_t': clinical_t,
        'ajcc_clinical_n': clinical_n,
        'ajcc_clinical_m': clinical_m
    })

# %%
# Example usage
root_folder = './tcga_hnsc_xml_clinical'  # Specify your root folder here

# Process all XML files and get the consolidated DataFrame
df = process_xml_files(root_folder)

# %%
radiation_columns = extract_and_organize_drugs(df,"patient.radiations.radiation")
reordered_columns_df_1 = pd.concat([df.drop(columns=radiation_columns), df[radiation_columns]], axis=1)

drug_columns = extract_and_organize_drugs(reordered_columns_df_1)
reordered_columns_df_2 = pd.concat([reordered_columns_df_1.drop(columns=drug_columns), reordered_columns_df_1[drug_columns]], axis=1)

follow_up_columns = extract_and_organize_followup(reordered_columns_df_2)
reordered_columns_df_3 = pd.concat([reordered_columns_df_2.drop(columns=follow_up_columns), reordered_columns_df_2[follow_up_columns]], axis=1)

# %% [markdown]
# 1. Remove follow_up, radiation and drug information

# %%
new_df = reordered_columns_df_3.loc[:, ~reordered_columns_df_3.columns.str.contains("patient.follow_ups|patient.radiations|patient.drugs")]

# %% [markdown]
# 2. Need to keep patient.bcr_patient_barcode and patient.bcr_patient_uuid for WSI mapping. remove other ID related fields (admin.file_uuid,admin.batch_number,patient.patient_id).

# %%
new_df = new_df.drop(["admin.file_uuid", "admin.batch_number", "patient.patient_id"], axis=1)
#remove: admin.file_uuid, admin.batch_numer, patient.patient_id,

# %% [markdown]
# 3. Remove values that are post-treatment

# %%
new_df = new_df.drop(columns=[
    "patient.radiation_therapy",
    "patient.postoperative_rx_tx",
    "patient.primary_therapy_outcome_success",
    "patient.stage_event.pathologic_stage",
    "patient.stage_event.tnm_categories.pathologic_categories.pathologic_T",
    "patient.stage_event.tnm_categories.pathologic_categories.pathologic_N",
    "patient.stage_event.tnm_categories.pathologic_categories.pathologic_M",
    "patient.margin_status",
    "patient.presence_of_pathological_nodal_extracapsular_spread",
    "patient.lymphovascular_invasion_present",
    "patient.perineural_invasion_present",
    "patient.new_tumor_events.new_tumor_event_after_initial_treatment",
    "patient.new_tumor_events.new_tumor_event.days_to_new_tumor_event_after_initial_treatment",
    "patient.new_tumor_events.new_tumor_event.new_neoplasm_event_occurrence_anatomic_site",
    "patient.new_tumor_events.new_tumor_event.new_neoplasm_occurrence_anatomic_site_text",
    "patient.new_tumor_events.new_tumor_event.progression_determined_by",
    "patient.new_tumor_events.new_tumor_event.new_tumor_event_additional_surgery_procedure",
    "patient.new_tumor_events.new_tumor_event.additional_radiation_therapy",
    "patient.new_tumor_events.new_tumor_event.additional_pharmaceutical_therapy",
    "patient.new_tumor_events.new_tumor_event.new_neoplasm_event_type",
    "patient.new_tumor_events.new_tumor_event.days_to_new_tumor_event_additional_surgery_procedure",
    "patient.vital_status",
    "patient.days_to_last_followup",
    "patient.days_to_death",
    "patient.days_to_last_known_alive",
    "patient.number_of_lymphnodes_positive_by_ihc",
    "patient.neoplasm_histologic_grade",
    "patient.history_of_neoadjuvant_treatment",
    "patient.lymph_node_examined_count",
    "patient.number_of_lymphnodes_positive_by_he",
    "patient.lymphnode_neck_dissection",
    "patient.lymphnode_dissection_method_left",
    "patient.lymphnode_dissection_method_right",
    "patient.person_neoplasm_cancer_status",
    "patient.primary_lymph_node_presentation_assessment"
])

# %% [markdown]
# 4. Remove values that are empty or useless

# %%
new_df = new_df.drop(columns=[
    "patient.tissue_prospective_collection_indicator",
    "patient.tissue_retrospective_collection_indicator",
    "patient.tissue_source_site",
    "patient.days_to_initial_pathologic_diagnosis",
    "patient.year_of_initial_pathologic_diagnosis",
    "patient.day_of_form_completion",
    "patient.month_of_form_completion",
    "patient.year_of_form_completion",
    "patient.age_at_initial_pathologic_diagnosis" #removed because there is already "days_to_birth" available which is in days. 
])

# %%
# Create a copy of clinical_data for processing
clinical_data_filtered = new_df.copy()

# Step 1: Mapping 4th/5th edition to 6th edition
mask_5th = clinical_data_filtered['patient.stage_event.system_version'].isin(['4th', '5th'])
df_filtered_5th = clinical_data_filtered[mask_5th].copy()

# Apply the 5th to 6th mapping
mapped_values_5th = df_filtered_5th.apply(map_clinical_5th_to_6th, axis=1)
df_filtered_5th.update(mapped_values_5th)

# Update clinical_data_filtered to include the new 6th edition values
clinical_data_filtered.update(df_filtered_5th)

# Step 2: Mapping 6th edition (including 5th-to-6th mapped) to 7th edition
mask_6th_combined = clinical_data_filtered['patient.stage_event.system_version'].isin(['4th', '5th', '6th'])
df_filtered_6th = clinical_data_filtered[mask_6th_combined].copy()

# Apply the 6th to 7th mapping
mapped_values_6th_to_7th = df_filtered_6th.apply(map_clinical_6th_to_7th, axis=1)
df_filtered_6th.update(mapped_values_6th_to_7th)

# Directly update clinical_data_filtered with 6th-to-7th mapped values
clinical_data_filtered.update(df_filtered_6th)

# Final processed DataFrame
clinical_data_updated = clinical_data_filtered

# %%
clinical_data_final = clinical_data_updated.drop('patient.stage_event.system_version', axis=1)


for column in clinical_data_final.columns:
    print(f"Column: {column}")
    value_counts = clinical_data_final[column].value_counts(normalize=True,dropna=False) * 100
    for value, percentage in value_counts.items():
        print(f"  Value: {value}, Percentage: {percentage:.2f}%")
    print("\n" + "="*50 + "\n")
# Out:
# Column: patient.histological_type
#   Value: Head & Neck Squamous Cell Carcinoma, Percentage: 97.92%
#   Value: Head & Neck Squamous Cell Carcinoma Basaloid Type, Percentage: 1.89%
#   Value: Head & Neck Squamous Cell Carcinoma, Spindle Cell Variant, Percentage: 0.19%
#
# ==================================================
#
# Column: patient.gender
#   Value: MALE, Percentage: 73.11%
#   Value: FEMALE, Percentage: 26.89%
#
# ==================================================
#
# Column: patient.days_to_birth
#   Value: -17125, Percentage: 0.38%
#   Value: -18812, Percentage: 0.38%
#   Value: -18718, Percentage: 0.38%
#   Value: -28221, Percentage: 0.38%
#   Value: -25020, Percentage: 0.38%
#   Value: -24558, Percentage: 0.38%
#   Value: -22182, Percentage: 0.38%
#   Value: -18536, Percentage: 0.38%
#   Value: -22836, Percentage: 0.19%
#   Value: -20464, Percentage: 0.19%
#   Value: -20386, Percentage: 0.19%
#   Value: -18272, Percentage: 0.19%
#   Value: -27261, Percentage: 0.19%
#   Value: -22828, Percentage: 0.19%
#   Value: -22455, Percentage: 0.19%
#   Value: -20175, Percentage: 0.19%
#   Value: -29530, Percentage: 0.19%
#   Value: -17471, Percentage: 0.19%
#   Value: -21232, Percentage: 0.19%
#   Value: -16610, Percentage: 0.19%
#   Value: -24222, Percentage: 0.19%
#   Value: -26569, Percentage: 0.19%
#   Value: -20868, Percentage: 0.19%
#   Value: -25379, Percentage: 0.19%
#   Value: -24106, Percentage: 0.19%
#   Value: -25366, Percentage: 0.19%
#   Value: -27708, Percentage: 0.19%
#   Value: -21979, Percentage: 0.19%
#   Value: -27459, Percentage: 0.19%
#   Value: -25138, Percentage: 0.19%
#   Value: -21041, Percentage: 0.19%
#   Value: -19747, Percentage: 0.19%
#   Value: -21890, Percentage: 0.19%
#   Value: -30095, Percentage: 0.19%
#   Value: -17873, Percentage: 0.19%
#   Value: -22125, Percentage: 0.19%
#   Value: -18194, Percentage: 0.19%
#   Value: -23955, Percentage: 0.19%
#   Value: -29465, Percentage: 0.19%
#   Value: -22279, Percentage: 0.19%
#   Value: -20783, Percentage: 0.19%
#   Value: -25363, Percentage: 0.19%
#   Value: -23310, Percentage: 0.19%
#   Value: -26687, Percentage: 0.19%
#   Value: -24259, Percentage: 0.19%
#   Value: -25592, Percentage: 0.19%
#   Value: -25942, Percentage: 0.19%
#   Value: -22857, Percentage: 0.19%
#   Value: -23035, Percentage: 0.19%
#   Value: -22934, Percentage: 0.19%
#   Value: -20306, Percentage: 0.19%
#   Value: -23071, Percentage: 0.19%
#   Value: -23984, Percentage: 0.19%
#   Value: -18143, Percentage: 0.19%
#   Value: -15477, Percentage: 0.19%
#   Value: -19518, Percentage: 0.19%
#   Value: -18404, Percentage: 0.19%
#   Value: -20703, Percentage: 0.19%
#   Value: -19447, Percentage: 0.19%
#   Value: -22307, Percentage: 0.19%
#   Value: -32022, Percentage: 0.19%
#   Value: -32871, Percentage: 0.19%
#   Value: -19797, Percentage: 0.19%
#   Value: -22246, Percentage: 0.19%
Percentage: 0.19%
#
# ==================================================
#
# Column: patient.race_list.race
#   Value: WHITE, Percentage: 85.61%
#   Value: BLACK OR AFRICAN AMERICAN, Percentage: 9.09%
#   Value: nan, Percentage: 2.84%
#   Value: ASIAN, Percentage: 2.08%
#   Value: AMERICAN INDIAN OR ALASKA NATIVE, Percentage: 0.38%
#
# ==================================================
#
# Column: patient.bcr_patient_barcode
#   Value: TCGA-UF-A718, Percentage: 0.19%
#   Value: TCGA-CN-5374, Percentage: 0.19%
#   Value: TCGA-CV-6960, Percentage: 0.19%
#   Value: TCGA-CV-A461, Percentage: 0.19%
#   Value: TCGA-DQ-7588, Percentage: 0.19%
#   Value: TCGA-CR-6491, Percentage: 0.19%
#   Value: TCGA-CR-7372, Percentage: 0.19%
#   Value: TCGA-CR-7374, Percentage: 0.19%
#   Value: TCGA-CN-6020, Percentage: 0.19%
#   Value: TCGA-DQ-7594, Percentage: 0.19%
#   Value: TCGA-CQ-7068, Percentage: 0.19%
#   Value: TCGA-D6-A4ZB, Percentage: 0.19%
#   Value: TCGA-CN-4730, Percentage: 0.19%
#   Value: TCGA-CV-6955, Percentage: 0.19%
#   Value: TCGA-CN-A63U, Percentage: 0.19%
#   Value: TCGA-MT-A67D, Percentage: 0.19%
#   Value: TCGA-4P-AA8J, Percentage: 0.19%
#   Value: TCGA-D6-A4Z9, Percentage: 0.19%
#   Value: TCGA-D6-6827, Percentage: 0.19%
#   Value: TCGA-CV-A45O, Percentage: 0.19%
#   Value: TCGA-CV-A45Q, Percentage: 0.19%
#   Value: TCGA-BA-5151, Percentage: 0.19%
#   Value: TCGA-CQ-6220, Percentage: 0.19%
#   Value: TCGA-BA-6871, Percentage: 0.19%
#   Value: TCGA-QK-A8ZA, Percentage: 0.19%
#   Value: TCGA-UF-A7J9, Percentage: 0.19%
#   Value: TCGA-CR-7402, Percentage: 0.19%
#   Value: TCGA-DQ-7592, Percentage: 0.19%
#   Value: TCGA-HD-8634, Percentage: 0.19%
#   Value: TCGA-UF-A71D, Percentage: 0.19%
#   Value: TCGA-CV-5970, Percentage: 0.19%
#   Value: TCGA-CV-A463, Percentage: 0.19%
#   Value: TCGA-CV-6937, Percentage: 0.19%
#   Value: TCGA-CV-6959, Percentage: 0.19%
#   Value: TCGA-CR-7388, Percentage: 0.19%
#   Value: TCGA-CN-5367, Percentage: 0.19%
#   Value: TCGA-CQ-6222, Percentage: 0.19%
#   Value: TCGA-MT-A67G, Percentage: 0.19%
#   Value: TCGA-P3-A6T6, Percentage: 0.19%
#   Value: TCGA-HD-7229, Percentage: 0.19%
#   Value: TCGA-CV-5971, Percentage: 0.19%
#   Value: TCGA-BA-5152, Percentage: 0.19%
#   Value: TCGA-WA-A7H4, Percentage: 0.19%
#   Value: TCGA-CN-A497, Percentage: 0.19%
#   Value: TCGA-BB-4225, Percentage: 0.19%
#   Value: TCGA-CN-6024, Percentage: 0.19%
#   Value: TCGA-F7-A623, Percentage: 0.19%
#   Value: TCGA-CQ-6228, Percentage: 0.19%
#   Value: TCGA-BA-A6DI, Percentage: 0.19%
#   Value: TCGA-BB-4228, Percentage: 0.19%
#   Value: TCGA-IQ-A61I, Percentage: 0.19%
#   Value: TCGA-CV-7252, Percentage: 0.19%
#   Value: TCGA-CV-7254, Percentage: 0.19%
#   Value: TCGA-UF-A71E, Percentage: 0.19%
#   Value: TCGA-CV-6953, Percentage: 0.19%
#   Value: TCGA-BA-5558, Percentage: 0.19%
#   Value: TCGA-CR-7385, Percentage: 0.19%
#   Value: TCGA-CV-6933, Percentage: 0.19%
#   Value: TCGA-UF-A71B, Percentage: 0.19%
#   Value: TCGA-CN-6013, Percentage: 0.19%
#   Value: TCGA-CN-6998, Percentage: 0.19%
#   Value: TCGA-CQ-5327, Percentage: 0.19%
#   Value: TCGA-CV-7095, Percentage: 0.19%
#   Value: TCGA-CN-5369, Percentage: 0.19%
#   Value: TCGA-UF-A719, Percentage: 0.19%
#   Value: TCGA-F7-8489, Percentage: 0.19%
#   Value: TCGA-CV-5435, Percentage: 0.19%
#   Value: TCGA-P3-A6T3, Percentage: 0.19%
#   Value: TCGA-BB-A6UO, Percentage: 0.19%
#   Value: TCGA-CV-7090, Percentage: 0.19%
#   Value: TCGA-BA-6872, Percentage: 0.19%
#   Value: TCGA-CV-7407, Percentage: 0.19%
#   Value: TCGA-CV-6433, Percentage: 0.19%
#   Value: TCGA-BB-A5HY, Percentage: 0.19%
#   Value: TCGA-MT-A51W, Percentage: 0.19%
#   Value: TCGA-CX-7219, Percentage: 0.19%
#   Value: TCGA-TN-A7HL, Percentage: 0.19%
#   Value: TCGA-BA-A6DE, Percentage: 0.19%
#   Value: TCGA-P3-A5Q6, Percentage: 0.19%
#   Value: TCGA-CV-7446, Percentage: 0.19%
#   Value: TCGA-CN-A49B, Percentage: 0.19%
#   Value: TCGA-CN-6022, Percentage: 0.19%
#   Value: TCGA-BB-7861, Percentage: 0.19%
#   Value: TCGA-CV-5439, Percentage: 0.19%
#   Value: TCGA-CQ-A4CA, Percentage: 0.19%
#   Value: TCGA-CQ-6219, Percentage: 0.19%
#   Value: TCGA-QK-AA3J, Percentage: 0.19%
#   Value: TCGA-BA-6868, Percentage: 0.19%
#   Value: TCGA-CN-4739, Percentage: 0.19%
#   Value: TCGA-UP-A6WW, Percentage: 0.19%
#   Value: TCGA-CN-A6V3, Percentage: 0.19%
#   Value: TCGA-CR-7397, Percentage: 0.19%
#   Value: TCGA-CV-7250, Percentage: 0.19%
#   Value: TCGA-KU-A6H8, Percentage: 0.19%
#   Value: TCGA-CN-A63V, Percentage: 0.19%
#   Value: TCGA-BA-6869, Percentage: 0.19%
#   Value: TCGA-CQ-6225, Percentage: 0.19%
#   Value: TCGA-CQ-A4CE, Percentage: 0.19%
#   Value: TCGA-BA-A6DJ, Percentage: 0.19%
#   Value: TCGA-CN-4741, Percentage: 0.19%
#   Value: TCGA-CN-5361, Percentage: 0.19%
#   Value: TCGA-CR-7382, Percentage: 0.19%
#   Value: TCGA-IQ-A61H, Percentage: 0.19%
#   Value: TCGA-CN-5355, Percentage: 0.19%
#   Value: TCGA-CV-7261, Percentage: 0.19%
#   Value: TCGA-CV-6952, Percentage: 0.19%
#   Value: TCGA-CV-7410, Percentage: 0.19%
#   Value: TCGA-CV-7568, Percentage: 0.19%
#   Value: TCGA-CV-A45W, Percentage: 0.19%
#   Value: TCGA-HD-A6HZ, Percentage: 0.19%
#   Value: TCGA-BA-A6DA, Percentage: 0.19%
#   Value: TCGA-CN-4728, Percentage: 0.19%
#   Value: TCGA-DQ-5629, Percentage: 0.19%
#   Value: TCGA-UF-A7JH, Percentage: 0.19%
#   Value: TCGA-CQ-5334, Percentage: 0.19%
#   Value: TCGA-CN-4729, Percentage: 0.19%
#   Value: TCGA-IQ-A61J, Percentage: 0.19%
#   Value: TCGA-CV-7416, Percentage: 0.19%
#   Value: TCGA-H7-A6C4, Percentage: 0.19%
#   Value: TCGA-CV-5973, Percentage: 0.19%
#   Value: TCGA-CQ-5323, Percentage: 0.19%
#   Value: TCGA-CQ-A4CI, Percentage: 0.19%
#   Value: TCGA-WA-A7GZ, Percentage: 0.19%
#   Value: TCGA-CN-4734, Percentage: 0.19%
#   Value: TCGA-BA-A6DG, Percentage: 0.19%
#   Value: TCGA-CV-7183, Percentage: 0.19%
#   Value: TCGA-CN-4726, Percentage: 0.19%
#   Value: TCGA-C9-A47Z, Percentage: 0.19%
#   Value: TCGA-CN-5358, Percentage: 0.19%
#   Value: TCGA-D6-6516, Percentage: 0.19%
#   Value: TCGA-CN-6996, Percentage: 0.19%
#   Value: TCGA-CV-A6JU, Percentage: 0.19%
#   Value: TCGA-CV-7423, Percentage: 0.19%
#   Value: TCGA-CN-5365, Percentage: 0.19%
#   Value: TCGA-QK-A6IG, Percentage: 0.19%
#   Value: TCGA-CR-6473, Percentage: 0.19%
#   Value: TCGA-F7-A50J, Percentage: 0.19%
#   Value: TCGA-CN-A6UY, Percentage: 0.19%
#   Value: TCGA-CN-6011, Percentage: 0.19%
#   Value: TCGA-CV-7104, Percentage: 0.19%
#   Value: TCGA-CN-6019, Percentage: 0.19%
#   Value: TCGA-CV-5979, Percentage: 0.19%
#   Value: TCGA-CN-6010, Percentage: 0.19%
#   Value: TCGA-P3-A6T4, Percentage: 0.19%
#   Value: TCGA-CN-5363, Percentage: 0.19%
#   Value: TCGA-HD-A4C1, Percentage: 0.19%
#   Value: TCGA-CV-7253, Percentage: 0.19%
#   Value: TCGA-P3-A6T0, Percentage: 0.19%
#   Value: TCGA-CV-A468, Percentage: 0.19%
#   Value: TCGA-CN-6021, Percentage: 0.19%
#   Value: TCGA-CR-7391, Percentage: 0.19%
#   Value: TCGA-CV-7248, Percentage: 0.19%
#   Value: TCGA-DQ-7595, Percentage: 0.19%
#   Value: TCGA-QK-AA3K, Percentage: 0.19%
#   Value: TCGA-CQ-6218, Percentage: 0.19%
#   Value: TCGA-CV-7245, Percentage: 0.19%
#   Value: TCGA-CR-6493, Percentage: 0.19%
#   Value: TCGA-IQ-7631, Percentage: 0.19%
#   Value: TCGA-P3-A5Q5, Percentage: 0.19%
#   Value: TCGA-CQ-A4CD, Percentage: 0.19%
#   Value: TCGA-CN-4733, Percentage: 0.19%
#   Value: TCGA-CQ-5324, Percentage: 0.19%
#   Value: TCGA-CV-7102, Percentage: 0.19%
#   Value: TCGA-CV-A6JD, Percentage: 0.19%
#   Value: TCGA-CN-5373, Percentage: 0.19%
#   Value: TCGA-CN-4727, Percentage: 0.19%
#   Value: TCGA-CV-7411, Percentage: 0.19%
#   Value: TCGA-CV-6942, Percentage: 0.19%
#   Value: TCGA-BA-5556, Percentage: 0.19%
#   Value: TCGA-QK-A6V9, Percentage: 0.19%
#   Value: TCGA-CQ-6227, Percentage: 0.19%
#   Value: TCGA-CR-7371, Percentage: 0.19%
#   Value: TCGA-CQ-7067, Percentage: 0.19%
#   Value: TCGA-CN-A642, Percentage: 0.19%
#   Value: TCGA-CV-A460, Percentage: 0.19%
#   Value: TCGA-CV-6436, Percentage: 0.19%
#   Value: TCGA-UF-A7JJ, Percentage: 0.19%
#   Value: TCGA-DQ-7596, Percentage: 0.19%
#   Value: TCGA-MT-A51X, Percentage: 0.19%
#   Value: TCGA-RS-A6TP, Percentage: 0.19%
#   Value: TCGA-CV-5440, Percentage: 0.19%
#   Value: TCGA-CN-6997, Percentage: 0.19%
#   Value: TCGA-F7-A50I, Percentage: 0.19%
#   Value: TCGA-CV-5976, Percentage: 0.19%
#   Value: TCGA-BB-8596, Percentage: 0.19%
#   Value: TCGA-CR-6478, Percentage: 0.19%
#   Value: TCGA-CV-7434, Percentage: 0.19%
#   Value: TCGA-CV-A6K1, Percentage: 0.19%
#   Value: TCGA-CX-7082, Percentage: 0.19%
#   Value: TCGA-CN-6988, Percentage: 0.19%
#   Value: TCGA-HL-7533, Percentage: 0.19%
#   Value: TCGA-CV-6441, Percentage: 0.19%
#   Value: TCGA-MT-A7BN, Percentage: 0.19%
#   Value: TCGA-IQ-7630, Percentage: 0.19%
#   Value: TCGA-CV-A6JE, Percentage: 0.19%
#   Value: TCGA-CV-6003, Percentage: 0.19%
#   Value: TCGA-C9-A480, Percentage: 0.19%
#   Value: TCGA-P3-A6SX, Percentage: 0.19%
#   Value: TCGA-CV-7425, Percentage: 0.19%
#   Value: TCGA-CR-7404, Percentage: 0.19%
#   Value: TCGA-CQ-6223, Percentage: 0.19%
#   Value: TCGA-BA-6870, Percentage: 0.19%
#   Value: TCGA-QK-A8Z9, Percentage: 0.19%
#   Value: TCGA-CQ-7063, Percentage: 0.19%
#   Value: TCGA-T2-A6X2, Percentage: 0.19%
#   Value: TCGA-CN-6012, Percentage: 0.19%
#   Value: TCGA-F7-A61V, Percentage: 0.19%
#   Value: TCGA-CR-7394, Percentage: 0.19%
#   Value: TCGA-CV-7421, Percentage: 0.19%
#   Value: TCGA-CV-7437, Percentage: 0.19%
#   Value: TCGA-CV-6961, Percentage: 0.19%
#   Value: TCGA-CR-7364, Percentage: 0.19%
#   Value: TCGA-CN-4737, Percentage: 0.19%
#   Value: TCGA-F7-8298, Percentage: 0.19%
#   Value: TCGA-D6-6824, Percentage: 0.19%
#   Value: TCGA-MZ-A5BI, Percentage: 0.19%
#   Value: TCGA-CV-6935, Percentage: 0.19%
#   Value: TCGA-F7-A50G, Percentage: 0.19%
#   Value: TCGA-CN-A63Y, Percentage: 0.19%
#   Value: TCGA-KU-A66S, Percentage: 0.19%
#   Value: TCGA-CR-6480, Percentage: 0.19%
#   Value: TCGA-CR-7376, Percentage: 0.19%
#   Value: TCGA-CV-A45R, Percentage: 0.19%
#   Value: TCGA-T2-A6X0, Percentage: 0.19%
#   Value: TCGA-MZ-A7D7, Percentage: 0.19%
#   Value: TCGA-T2-A6WX, Percentage: 0.19%
#   Value: TCGA-CV-7413, Percentage: 0.19%
#   Value: TCGA-CR-7390, Percentage: 0.19%
#   Value: TCGA-CV-7415, Percentage: 0.19%
#   Value: TCGA-CR-6467, Percentage: 0.19%
#   Value: TCGA-CN-5366, Percentage: 0.19%
#   Value: TCGA-IQ-A61G, Percentage: 0.19%
#   Value: TCGA-CR-7377, Percentage: 0.19%
#   Value: TCGA-MT-A67A, Percentage: 0.19%
#   Value: TCGA-HD-7753, Percentage: 0.19%
#   Value: TCGA-QK-A6VB, Percentage: 0.19%
#   Value: TCGA-D6-6823, Percentage: 0.19%
#   Value: TCGA-CV-7089, Percentage: 0.19%
#   Value: TCGA-CV-6941, Percentage: 0.19%
#   Value: TCGA-CV-6943, Percentage: 0.19%
#   Value: TCGA-CV-5430, Percentage: 0.19%
#   Value: TCGA-BB-A5HZ, Percentage: 0.19%
#   Value: TCGA-BA-4078, Percentage: 0.19%
#   Value: TCGA-F7-A61W, Percentage: 0.19%
#   Value: TCGA-CR-6481, Percentage: 0.19%
#   Value: TCGA-BA-A4IH, Percentage: 0.19%
#   Value: TCGA-CV-6945, Percentage: 0.19%
#   Value: TCGA-BA-A6DB, Percentage: 0.19%
#   Value: TCGA-BA-A6D8, Percentage: 0.19%
#   Value: TCGA-BA-5149, Percentage: 0.19%
#   Value: TCGA-CQ-5330, Percentage: 0.19%
#   Value: TCGA-CR-7401, Percentage: 0.19%
#   Value: TCGA-F7-A624, Percentage: 0.19%
#   Value: TCGA-QK-A652, Percentage: 0.19%
#   Value: TCGA-CV-6936, Percentage: 0.19%
#   Value: TCGA-H7-7774, Percentage: 0.19%
#   Value: TCGA-D6-8569, Percentage: 0.19%
#   Value: TCGA-D6-8568, Percentage: 0.19%
#   Value: TCGA-CQ-5331, Percentage: 0.19%
#   Value: TCGA-CN-A49C, Percentage: 0.19%
#   Value: TCGA-CV-A45T, Percentage: 0.19%
#   Value: TCGA-BA-A4IG, Percentage: 0.19%
#   Value: TCGA-D6-6515, Percentage: 0.19%
#   Value: TCGA-QK-A8ZB, Percentage: 0.19%
#   Value: TCGA-CR-7389, Percentage: 0.19%
#   Value: TCGA-CR-7383, Percentage: 0.19%
#   Value: TCGA-BB-4224, Percentage: 0.19%
#   Value: TCGA-BB-7866, Percentage: 0.19%
#   Value: TCGA-CV-A45V, Percentage: 0.19%
#   Value: TCGA-F7-A61S, Percentage: 0.19%
#   Value: TCGA-BB-7863, Percentage: 0.19%
#   Value: TCGA-CN-6017, Percentage: 0.19%
#   Value: TCGA-UF-A7JF, Percentage: 0.19%
#   Value: TCGA-CV-5444, Percentage: 0.19%
#   Value: TCGA-CN-4742, Percentage: 0.19%
#   Value: TCGA-QK-A6VC, Percentage: 0.19%
#   Value: TCGA-CR-7369, Percentage: 0.19%
#   Value: TCGA-CR-6471, Percentage: 0.19%
#   Value: TCGA-CV-7242, Percentage: 0.19%
#   Value: TCGA-CV-A6JO, Percentage: 0.19%
#   Value: TCGA-DQ-5625, Percentage: 0.19%
#   Value: TCGA-H7-A6C5, Percentage: 0.19%
#   Value: TCGA-CN-A641, Percentage: 0.19%
#   Value: TCGA-CV-A6JZ, Percentage: 0.19%
#   Value: TCGA-CV-7255, Percentage: 0.19%
#   Value: TCGA-CV-5434, Percentage: 0.19%
#   Value: TCGA-MZ-A6I9, Percentage: 0.19%
#   Value: TCGA-CV-7433, Percentage: 0.19%
#   Value: TCGA-CR-6488, Percentage: 0.19%
#   Value: TCGA-HD-A634, Percentage: 0.19%
#   Value: TCGA-CV-7440, Percentage: 0.19%
#   Value: TCGA-DQ-7593, Percentage: 0.19%
#   Value: TCGA-CR-5249, Percentage: 0.19%
#   Value: TCGA-CV-A45P, Percentage: 0.19%
#   Value: TCGA-CQ-A4CH, Percentage: 0.19%
#   Value: TCGA-QK-A8Z7, Percentage: 0.19%
#   Value: TCGA-CR-7365, Percentage: 0.19%
#   Value: TCGA-QK-A6II, Percentage: 0.19%
#   Value: TCGA-D6-6826, Percentage: 0.19%
#   Value: TCGA-CN-A640, Percentage: 0.19%
#   Value: TCGA-CV-5431, Percentage: 0.19%
#   Value: TCGA-H7-8502, Percentage: 0.19%
#   Value: TCGA-CV-5442, Percentage: 0.19%
#   Value: TCGA-CN-6995, Percentage: 0.19%
#   Value: TCGA-HD-8635, Percentage: 0.19%
#   Value: TCGA-IQ-A6SH, Percentage: 0.19%
#   Value: TCGA-UF-A7JA, Percentage: 0.19%
#   Value: TCGA-CV-7263, Percentage: 0.19%
#   Value: TCGA-CV-A6K0, Percentage: 0.19%
#   Value: TCGA-CV-6940, Percentage: 0.19%
#   Value: TCGA-UF-A7JK, Percentage: 0.19%
#   Value: TCGA-BA-5557, Percentage: 0.19%
#   Value: TCGA-CV-A465, Percentage: 0.19%
#   Value: TCGA-CV-7435, Percentage: 0.19%
#   Value: TCGA-CR-7386, Percentage: 0.19%
#   Value: TCGA-CV-7406, Percentage: 0.19%
#   Value: TCGA-D6-A6EM, Percentage: 0.19%
#   Value: TCGA-CV-7247, Percentage: 0.19%
#   Value: TCGA-QK-A64Z, Percentage: 0.19%
#   Value: TCGA-T3-A92N, Percentage: 0.19%
#   Value: TCGA-CN-4723, Percentage: 0.19%
#   Value: TCGA-CV-6956, Percentage: 0.19%
#   Value: TCGA-HD-7917, Percentage: 0.19%
#   Value: TCGA-CN-6016, Percentage: 0.19%
#   Value: TCGA-CV-6938, Percentage: 0.19%
#   Value: TCGA-BA-A4II, Percentage: 0.19%
#   Value: TCGA-T3-A92M, Percentage: 0.19%
#   Value: TCGA-CR-5248, Percentage: 0.19%
#   Value: TCGA-CV-7438, Percentage: 0.19%
#   Value: TCGA-BA-A6DD, Percentage: 0.19%
#   Value: TCGA-CV-7427, Percentage: 0.19%
#   Value: TCGA-QK-A6IF, Percentage: 0.19%
#   Value: TCGA-F7-7848, Percentage: 0.19%
#   Value: TCGA-D6-A6EN, Percentage: 0.19%
#   Value: TCGA-CQ-5329, Percentage: 0.19%
#   Value: TCGA-CV-7235, Percentage: 0.19%
#   Value: TCGA-CN-4735, Percentage: 0.19%
#   Value: TCGA-P3-A6T5, Percentage: 0.19%
#   Value: TCGA-P3-A6T2, Percentage: 0.19%
#   Value: TCGA-D6-A6ES, Percentage: 0.19%
#   Value: TCGA-D6-6825, Percentage: 0.19%
#   Value: TCGA-CV-A6JT, Percentage: 0.19%
#   Value: TCGA-CQ-7064, Percentage: 0.19%
#   Value: TCGA-CN-4731, Percentage: 0.19%
#   Value: TCGA-CR-7379, Percentage: 0.19%
#   Value: TCGA-D6-6517, Percentage: 0.19%
#   Value: TCGA-CV-5432, Percentage: 0.19%
#   Value: TCGA-CN-6992, Percentage: 0.19%
#   Value: TCGA-CN-5360, Percentage: 0.19%
#   Value: TCGA-CV-A464, Percentage: 0.19%
#   Value: TCGA-CQ-7069, Percentage: 0.19%
#   Value: TCGA-CN-A49A, Percentage: 0.19%
#   Value: TCGA-IQ-7632, Percentage: 0.19%
#   Value: TCGA-CV-7103, Percentage: 0.19%
#   Value: TCGA-CV-6934, Percentage: 0.19%
#   Value: TCGA-BB-4217, Percentage: 0.19%
#   Value: TCGA-CN-4722, Percentage: 0.19%
#   Value: TCGA-BB-7870, Percentage: 0.19%
#   Value: TCGA-CV-7236, Percentage: 0.19%
#   Value: TCGA-CR-6470, Percentage: 0.19%
#   Value: TCGA-BB-7872, Percentage: 0.19%
#   Value: TCGA-BA-5555, Percentage: 0.19%
#   Value: TCGA-CR-7393, Percentage: 0.19%
#   Value: TCGA-CV-6954, Percentage: 0.19%
#   Value: TCGA-CN-A498, Percentage: 0.19%
#   Value: TCGA-CQ-7065, Percentage: 0.19%
#   Value: TCGA-CR-6482, Percentage: 0.19%
#   Value: TCGA-CV-6939, Percentage: 0.19%
#   Value: TCGA-CQ-5326, Percentage: 0.19%
#   Value: TCGA-BB-A6UM, Percentage: 0.19%
#   Value: TCGA-P3-A6T7, Percentage: 0.19%
#   Value: TCGA-CX-7086, Percentage: 0.19%
#   Value: TCGA-P3-A6SW, Percentage: 0.19%
#   Value: TCGA-CN-A6V6, Percentage: 0.19%
#   Value: TCGA-CN-6018, Percentage: 0.19%
#   Value: TCGA-CR-7373, Percentage: 0.19%
#   Value: TCGA-CV-7418, Percentage: 0.19%
#   Value: TCGA-CV-7430, Percentage: 0.19%
#   Value: TCGA-CV-7422, Percentage: 0.19%
#   Value: TCGA-CV-6962, Percentage: 0.19%
#   Value: TCGA-QK-A6IH, Percentage: 0.19%
#   Value: TCGA-CN-4738, Percentage: 0.19%
#   Value: TCGA-BA-4074, Percentage: 0.19%
#   Value: TCGA-CV-A6JN, Percentage: 0.19%
#   Value: TCGA-BB-8601, Percentage: 0.19%
#   Value: TCGA-CN-5370, Percentage: 0.19%
#   Value: TCGA-BA-A6DF, Percentage: 0.19%
#   Value: TCGA-CQ-A4CG, Percentage: 0.19%
#   Value: TCGA-CV-7097, Percentage: 0.19%
#   Value: TCGA-QK-A6IJ, Percentage: 0.19%
#   Value: TCGA-CV-7180, Percentage: 0.19%
#   Value: TCGA-CQ-6224, Percentage: 0.19%
#   Value: TCGA-CR-5247, Percentage: 0.19%
#   Value: TCGA-CV-7177, Percentage: 0.19%
#   Value: TCGA-CN-5364, Percentage: 0.19%
#   Value: TCGA-F7-A620, Percentage: 0.19%
#   Value: TCGA-CN-4736, Percentage: 0.19%
#   Value: TCGA-IQ-A61L, Percentage: 0.19%
#   Value: TCGA-CR-7392, Percentage: 0.19%
#   Value: TCGA-CV-5966, Percentage: 0.19%
#   Value: TCGA-CV-5443, Percentage: 0.19%
#   Value: TCGA-CV-5978, Percentage: 0.19%
#   Value: TCGA-CQ-A4C6, Percentage: 0.19%
#   Value: TCGA-CV-7414, Percentage: 0.19%
#   Value: TCGA-CX-7085, Percentage: 0.19%
#   Value: TCGA-CV-A6JY, Percentage: 0.19%
#   Value: TCGA-BA-4075, Percentage: 0.19%
#   Value: TCGA-D6-A6EP, Percentage: 0.19%
#   Value: TCGA-CV-7100, Percentage: 0.19%
#   Value: TCGA-CV-7099, Percentage: 0.19%
#   Value: TCGA-CV-7432, Percentage: 0.19%
#   Value: TCGA-CQ-6221, Percentage: 0.19%
#   Value: TCGA-CN-A63W, Percentage: 0.19%
#   Value: TCGA-UF-A7JO, Percentage: 0.19%
#   Value: TCGA-BA-A4IF, Percentage: 0.19%
#   Value: TCGA-BA-A6DL, Percentage: 0.19%
#   Value: TCGA-UF-A7JD, Percentage: 0.19%
#   Value: TCGA-BB-7864, Percentage: 0.19%
#   Value: TCGA-CV-A45X, Percentage: 0.19%
#   Value: TCGA-CQ-5332, Percentage: 0.19%
#   Value: TCGA-CV-6950, Percentage: 0.19%
#   Value: TCGA-HD-7754, Percentage: 0.19%
#   Value: TCGA-UF-A7JC, Percentage: 0.19%
#   Value: TCGA-CV-7101, Percentage: 0.19%
#   Value: TCGA-CR-6492, Percentage: 0.19%
#   Value: TCGA-IQ-A61K, Percentage: 0.19%
#   Value: TCGA-BB-4223, Percentage: 0.19%
#   Value: TCGA-CN-4725, Percentage: 0.19%
#   Value: TCGA-CQ-7071, Percentage: 0.19%
#   Value: TCGA-HD-8314, Percentage: 0.19%
#   Value: TCGA-CV-5436, Percentage: 0.19%
#   Value: TCGA-BA-5559, Percentage: 0.19%
#   Value: TCGA-CV-7178, Percentage: 0.19%
#   Value: TCGA-CV-7238, Percentage: 0.19%
#   Value: TCGA-DQ-5624, Percentage: 0.19%
#   Value: TCGA-CR-6477, Percentage: 0.19%
#   Value: TCGA-CV-A45U, Percentage: 0.19%
#   Value: TCGA-F7-A622, Percentage: 0.19%
#   Value: TCGA-BB-7862, Percentage: 0.19%
#   Value: TCGA-CR-7380, Percentage: 0.19%
#   Value: TCGA-BB-4227, Percentage: 0.19%
#   Value: TCGA-P3-A5QA, Percentage: 0.19%
#   Value: TCGA-CR-7370, Percentage: 0.19%
#   Value: TCGA-CR-6472, Percentage: 0.19%
#   Value: TCGA-CX-A4AQ, Percentage: 0.19%
#   Value: TCGA-T2-A6WZ, Percentage: 0.19%
#   Value: TCGA-CR-7399, Percentage: 0.19%
#   Value: TCGA-CV-A6JM, Percentage: 0.19%
#   Value: TCGA-CN-6023, Percentage: 0.19%
#   Value: TCGA-CR-6484, Percentage: 0.19%
#   Value: TCGA-CN-5356, Percentage: 0.19%
#   Value: TCGA-CV-A45Z, Percentage: 0.19%
#   Value: TCGA-KU-A66T, Percentage: 0.19%
#   Value: TCGA-CQ-A4CB, Percentage: 0.19%
#   Value: TCGA-BB-7871, Percentage: 0.19%
#   Value: TCGA-HD-8224, Percentage: 0.19%
#   Value: TCGA-CV-6951, Percentage: 0.19%
#   Value: TCGA-H7-A76A, Percentage: 0.19%
#   Value: TCGA-BA-7269, Percentage: 0.19%
#   Value: TCGA-CN-4740, Percentage: 0.19%
#   Value: TCGA-D6-A74Q, Percentage: 0.19%
#   Value: TCGA-CN-A63T, Percentage: 0.19%
#   Value: TCGA-CV-7424, Percentage: 0.19%
#   Value: TCGA-CV-A6K2, Percentage: 0.19%
#   Value: TCGA-CR-5243, Percentage: 0.19%
#   Value: TCGA-CN-6989, Percentage: 0.19%
#   Value: TCGA-CN-6994, Percentage: 0.19%
#   Value: TCGA-HD-7831, Percentage: 0.19%
#   Value: TCGA-IQ-A6SG, Percentage: 0.19%
#   Value: TCGA-HD-7832, Percentage: 0.19%
#   Value: TCGA-UF-A7JS, Percentage: 0.19%
#   Value: TCGA-CV-7243, Percentage: 0.19%
#   Value: TCGA-CV-6948, Percentage: 0.19%
#   Value: TCGA-CR-6487, Percentage: 0.19%
#   Value: TCGA-MT-A67F, Percentage: 0.19%
#   Value: TCGA-DQ-5631, Percentage: 0.19%
#   Value: TCGA-CQ-6229, Percentage: 0.19%
#   Value: TCGA-BA-6873, Percentage: 0.19%
#   Value: TCGA-BA-4076, Percentage: 0.19%
#   Value: TCGA-CN-A499, Percentage: 0.19%
#   Value: TCGA-DQ-5630, Percentage: 0.19%
#   Value: TCGA-RS-A6TO, Percentage: 0.19%
#   Value: TCGA-CR-7368, Percentage: 0.19%
#   Value: TCGA-D6-A6EK, Percentage: 0.19%
#   Value: TCGA-HD-A6I0, Percentage: 0.19%
#   Value: TCGA-CV-A45Y, Percentage: 0.19%
#   Value: TCGA-CQ-A4C7, Percentage: 0.19%
#   Value: TCGA-P3-A5QF, Percentage: 0.19%
#   Value: TCGA-BA-A8YP, Percentage: 0.19%
#   Value: TCGA-D6-A6EQ, Percentage: 0.19%
#   Value: TCGA-BB-A5HU, Percentage: 0.19%
#   Value: TCGA-DQ-7589, Percentage: 0.19%
#   Value: TCGA-CV-7409, Percentage: 0.19%
#   Value: TCGA-QK-A8Z8, Percentage: 0.19%
#   Value: TCGA-UF-A7JT, Percentage: 0.19%
#   Value: TCGA-CN-A6V7, Percentage: 0.19%
#   Value: TCGA-P3-A5QE, Percentage: 0.19%
#   Value: TCGA-DQ-7591, Percentage: 0.19%
#   Value: TCGA-CV-5441, Percentage: 0.19%
#   Value: TCGA-H7-8501, Percentage: 0.19%
Percentage: 0.19%
#
# ==================================================
#
# Column: patient.icd_10
#   Value: C02.9, Percentage: 24.81%
#   Value: C32.9, Percentage: 22.35%
#   Value: C14.8, Percentage: 13.26%
#   Value: C04.9, Percentage: 10.42%
#   Value: C09.9, Percentage: 7.95%
#   Value: C01, Percentage: 4.73%
#   Value: C06.9, Percentage: 4.36%
#   Value: C06.0, Percentage: 3.60%
#   Value: C10.9, Percentage: 2.08%
#   Value: C13.9, Percentage: 1.52%
#   Value: C03.9, Percentage: 1.52%
#   Value: C05.0, Percentage: 0.57%
#   Value: C00.9, Percentage: 0.57%
#   Value: C03.1, Percentage: 0.38%
#   Value: C04.0, Percentage: 0.38%
#   Value: C10.3, Percentage: 0.19%
#   Value: C32.1, Percentage: 0.19%
#   Value: C02.2, Percentage: 0.19%
#   Value: C02.1, Percentage: 0.19%
#   Value: C03.0, Percentage: 0.19%
#   Value: C06.2, Percentage: 0.19%
#   Value: C05.9, Percentage: 0.19%
#   Value: C41.1, Percentage: 0.19%
#
# ==================================================
#
# Column: patient.anatomic_neoplasm_subdivision
#   Value: Oral Tongue, Percentage: 25.19%
#   Value: Larynx, Percentage: 22.16%
#   Value: Oral Cavity, Percentage: 13.83%
#   Value: Floor of mouth, Percentage: 11.93%
#   Value: Tonsil, Percentage: 8.52%
#   Value: Base of tongue, Percentage: 5.11%
#   Value: Buccal Mucosa, Percentage: 4.36%
#   Value: Alveolar Ridge, Percentage: 3.41%
#   Value: Hypopharynx, Percentage: 1.89%
#   Value: Oropharynx, Percentage: 1.70%
#   Value: Hard Palate, Percentage: 1.33%
#   Value: Lip, Percentage: 0.57%
#
# ==================================================
#
# Column: patient.laterality
#   Value: nan, Percentage: 34.09%
#   Value: Right, Percentage: 31.82%
#   Value: Left, Percentage: 27.65%
#   Value: Midline, Percentage: 6.44%
#
# ==================================================
#
# Column: patient.tobacco_smoking_history
#   Value: 2, Percentage: 33.71%
#   Value: 4, Percentage: 26.52%
#   Value: 1, Percentage: 23.11%
#   Value: 3, Percentage: 13.83%
#   Value: nan, Percentage: 2.46%
#   Value: 5, Percentage: 0.38%
#
# ==================================================
#
# Column: patient.year_of_tobacco_smoking_onset
#   Value: nan, Percentage: 46.59%
#   Value: 1971, Percentage: 2.84%
#   Value: 1970, Percentage: 2.65%
#   Value: 1959, Percentage: 2.46%
#   Value: 1963, Percentage: 2.46%
#   Value: 1960, Percentage: 2.27%
#   Value: 1980, Percentage: 1.89%
#   Value: 1968, Percentage: 1.89%
#   Value: 1958, Percentage: 1.70%
#   Value: 1973, Percentage: 1.52%
#   Value: 1969, Percentage: 1.52%
#   Value: 1974, Percentage: 1.52%
#   Value: 1964, Percentage: 1.33%
#   Value: 1983, Percentage: 1.33%
#   Value: 1966, Percentage: 1.33%
#   Value: 1976, Percentage: 1.14%
#   Value: 1979, Percentage: 1.14%
#   Value: 1975, Percentage: 1.14%
#   Value: 1965, Percentage: 1.14%
#   Value: 1952, Percentage: 1.14%
#   Value: 1984, Percentage: 0.95%
#   Value: 1967, Percentage: 0.95%
#   Value: 1954, Percentage: 0.95%
#   Value: 1955, Percentage: 0.95%
#   Value: 1972, Percentage: 0.95%
#   Value: 1951, Percentage: 0.95%
#   Value: 1961, Percentage: 0.95%
#   Value: 1957, Percentage: 0.95%
#   Value: 1950, Percentage: 0.95%
#   Value: 1948, Percentage: 0.76%
#   Value: 1962, Percentage: 0.76%
#   Value: 1982, Percentage: 0.76%
#   Value: 1992, Percentage: 0.76%
#   Value: 1989, Percentage: 0.57%
#   Value: 1987, Percentage: 0.57%
#   Value: 1977, Percentage: 0.57%
#   Value: 1978, Percentage: 0.57%
#   Value: 1956, Percentage: 0.57%
#   Value: 1986, Percentage: 0.38%
#   Value: 1946, Percentage: 0.38%
#   Value: 1949, Percentage: 0.38%
#   Value: 1945, Percentage: 0.38%
#   Value: 1943, Percentage: 0.38%
#   Value: 1988, Percentage: 0.38%
#   Value: 1947, Percentage: 0.38%
#   Value: 2001, Percentage: 0.38%
#   Value: 1940, Percentage: 0.38%
#   Value: 1993, Percentage: 0.38%
#   Value: 1981, Percentage: 0.38%
#   Value: 1937, Percentage: 0.38%
#   Value: 1985, Percentage: 0.38%
#   Value: 1939, Percentage: 0.19%
#   Value: 1936, Percentage: 0.19%
#   Value: 1999, Percentage: 0.19%
#   Value: 1997, Percentage: 0.19%
#   Value: 1942, Percentage: 0.19%
#   Value: 1994, Percentage: 0.19%
#   Value: 1944, Percentage: 0.19%
#   Value: 1990, Percentage: 0.19%
#   Value: 1953, Percentage: 0.19%
#
# ==================================================
#
# Column: patient.number_pack_years_smoked
#   Value: nan, Percentage: 43.56%
#   Value: 40, Percentage: 7.20%
#   Value: 60, Percentage: 4.17%
#   Value: 30, Percentage: 3.60%
#   Value: 20, Percentage: 3.03%
#   Value: 50, Percentage: 2.65%
#   Value: 80, Percentage: 2.46%
#   Value: 25, Percentage: 2.27%
#   Value: 45, Percentage: 1.89%
#   Value: 15, Percentage: 1.52%
#   Value: 35, Percentage: 1.52%
#   Value: 10, Percentage: 1.33%
#   Value: 90, Percentage: 0.95%
#   Value: 75, Percentage: 0.95%
#   Value: 38, Percentage: 0.76%
#   Value: 43, Percentage: 0.76%
#   Value: 39, Percentage: 0.57%
#   Value: 100, Percentage: 0.57%
#   Value: 9, Percentage: 0.57%
#   Value: 5, Percentage: 0.57%
#   Value: 74, Percentage: 0.57%
#   Value: 14, Percentage: 0.57%
#   Value: 46, Percentage: 0.57%
#   Value: 25.5, Percentage: 0.57%
#   Value: 54, Percentage: 0.57%
#   Value: 21, Percentage: 0.57%
#   Value: 72, Percentage: 0.38%
#   Value: 66, Percentage: 0.38%
#   Value: 22, Percentage: 0.38%
#   Value: 12.5, Percentage: 0.38%
#   Value: 110, Percentage: 0.38%
#   Value: 3, Percentage: 0.38%
#   Value: 61, Percentage: 0.38%
#   Value: 67.5, Percentage: 0.38%
#   Value: 4, Percentage: 0.38%
#   Value: 150, Percentage: 0.38%
#   Value: 12, Percentage: 0.38%
#   Value: 26, Percentage: 0.38%
#   Value: 120, Percentage: 0.38%
#   Value: 300, Percentage: 0.38%
#   Value: 36, Percentage: 0.38%
#   Value: 11, Percentage: 0.38%
#   Value: 51, Percentage: 0.38%
#   Value: 16, Percentage: 0.38%
#   Value: 42, Percentage: 0.38%
#   Value: 41, Percentage: 0.38%
#   Value: 105, Percentage: 0.38%
#   Value: 1.5, Percentage: 0.19%
#   Value: 1.25, Percentage: 0.19%
#   Value: 68, Percentage: 0.19%
#   Value: 9.5, Percentage: 0.19%
#   Value: 108, Percentage: 0.19%
#   Value: 81, Percentage: 0.19%
#   Value: 180, Percentage: 0.19%
#   Value: 28, Percentage: 0.19%
#   Value: 47, Percentage: 0.19%
#   Value: 28.5, Percentage: 0.19%
#   Value: .9, Percentage: 0.19%
#   Value: 27, Percentage: 0.19%
#   Value: 62, Percentage: 0.19%
#   Value: 0.01685, Percentage: 0.19%
#   Value: 63, Percentage: 0.19%
#   Value: 102.5, Percentage: 0.19%
#   Value: 55, Percentage: 0.19%
#   Value: 135, Percentage: 0.19%
#   Value: 52, Percentage: 0.19%
#   Value: 23, Percentage: 0.19%
#   Value: 8, Percentage: 0.19%
#   Value: 53, Percentage: 0.19%
#   Value: 33, Percentage: 0.19%
#   Value: 70, Percentage: 0.19%
#   Value: 48, Percentage: 0.19%
#   Value: 64, Percentage: 0.19%
#   Value: 97.5, Percentage: 0.19%
#   Value: 57, Percentage: 0.19%
#   Value: 1, Percentage: 0.19%
#   Value: 49, Percentage: 0.19%
#   Value: 86, Percentage: 0.19%
#   Value: 37, Percentage: 0.19%
#   Value: 29, Percentage: 0.19%
#   Value: 6, Percentage: 0.19%
#   Value: .71, Percentage: 0.19%
#   Value: 5.1, Percentage: 0.19%
#   Value: 31, Percentage: 0.19%
#   Value: 112, Percentage: 0.19%
#   Value: 34, Percentage: 0.19%
#   Value: 82.5, Percentage: 0.19%
#   Value: 0.5, Percentage: 0.19%
#
# ==================================================
#
# Column: patient.alcohol_history_documented
#   Value: YES, Percentage: 66.67%
#   Value: NO, Percentage: 31.25%
#   Value: nan, Percentage: 2.08%
#
# ==================================================
#
# Column: patient.other_dx
#   Value: No, Percentage: 93.75%
#   Value: Yes, Percentage: 3.79%
#   Value: Yes, History of Prior Malignancy, Percentage: 1.33%
#   Value: Yes, History of Synchronous/Bilateral Malignancy, Percentage: 1.14%
#
# ==================================================
#
# Column: patient.stage_event.clinical_stage
#   Value: Stage IVA, Percentage: 50.95%
#   Value: Stage III, Percentage: 20.27%
#   Value: Stage II, Percentage: 18.75%
#   Value: Stage I, Percentage: 3.98%
#   Value: nan, Percentage: 2.65%
#   Value: Stage IVB, Percentage: 2.08%
#   Value: Stage IVC, Percentage: 1.33%
#
# ==================================================
#
# Column: patient.stage_event.tnm_categories.clinical_categories.clinical_T
#   Value: T4a, Percentage: 29.55%
#   Value: T2, Percentage: 28.79%
#   Value: T3, Percentage: 26.33%
#   Value: T1, Percentage: 7.01%
#   Value: T4, Percentage: 4.73%
#   Value: TX, Percentage: 2.27%
#   Value: nan, Percentage: 0.76%
#   Value: T4b, Percentage: 0.57%
#
# ==================================================
#
# Column: patient.stage_event.tnm_categories.clinical_categories.clinical_N
#   Value: N0, Percentage: 46.59%
#   Value: N2b, Percentage: 16.10%
#   Value: N1, Percentage: 16.10%
#   Value: N2c, Percentage: 8.52%
#   Value: N2, Percentage: 3.60%
#   Value: NX, Percentage: 3.41%
#   Value: N2a, Percentage: 3.22%
#   Value: N3, Percentage: 1.70%
#   Value: nan, Percentage: 0.76%
#
# ==================================================
#
# Column: patient.stage_event.tnm_categories.clinical_categories.clinical_M
#   Value: M0, Percentage: 93.94%
#   Value: MX, Percentage: 3.98%
#   Value: M1, Percentage: 1.14%
#   Value: nan, Percentage: 0.95%
#
# ==================================================
#
# Column: patient.ethnicity
#   Value: NOT HISPANIC OR LATINO, Percentage: 88.07%
#   Value: nan, Percentage: 7.01%
#   Value: HISPANIC OR LATINO, Percentage: 4.92%
#
# ==================================================
#
# Column: patient.stopped_smoking_year
#   Value: nan, Percentage: 64.39%
#   Value: 2011, Percentage: 3.03%
#   Value: 2012, Percentage: 2.08%
#   Value: 2010, Percentage: 1.89%
#   Value: 2005, Percentage: 1.89%
#   Value: 2009, Percentage: 1.70%
#   Value: 1996, Percentage: 1.52%
#   Value: 2006, Percentage: 1.33%
#   Value: 2013, Percentage: 1.33%
#   Value: 1999, Percentage: 1.14%
#   Value: 2001, Percentage: 1.14%
#   Value: 2008, Percentage: 0.95%
#   Value: 1998, Percentage: 0.95%
#   Value: 1997, Percentage: 0.95%
#   Value: 1994, Percentage: 0.95%
#   Value: 1980, Percentage: 0.76%
#   Value: 1979, Percentage: 0.76%
#   Value: 2003, Percentage: 0.76%
#   Value: 1995, Percentage: 0.76%
#   Value: 2000, Percentage: 0.76%
#   Value: 2002, Percentage: 0.76%
#   Value: 1988, Percentage: 0.57%
#   Value: 1976, Percentage: 0.57%
#   Value: 1985, Percentage: 0.57%
#   Value: 1992, Percentage: 0.57%
#   Value: 1993, Percentage: 0.57%
#   Value: 2004, Percentage: 0.57%
#   Value: 1968, Percentage: 0.38%
#   Value: 1986, Percentage: 0.38%
#   Value: 1987, Percentage: 0.38%
#   Value: 2007, Percentage: 0.38%
#   Value: 1989, Percentage: 0.38%
#   Value: 1991, Percentage: 0.38%
#   Value: 1981, Percentage: 0.38%
#   Value: 1990, Percentage: 0.38%
#   Value: 1983, Percentage: 0.38%
#   Value: 1975, Percentage: 0.38%
#   Value: 1978, Percentage: 0.19%
#   Value: 1967, Percentage: 0.19%
#   Value: 1961, Percentage: 0.19%
#   Value: 1971, Percentage: 0.19%
#   Value: 1974, Percentage: 0.19%
#   Value: 1962, Percentage: 0.19%
#   Value: 1963, Percentage: 0.19%
#   Value: 1982, Percentage: 0.19%
#   Value: 1969, Percentage: 0.19%
#   Value: 1965, Percentage: 0.19%
#   Value: 1956, Percentage: 0.19%
#   Value: 1973, Percentage: 0.19%
#   Value: 1964, Percentage: 0.19%
#   Value: 1955, Percentage: 0.19%
#   Value: 1984, Percentage: 0.19%
#   Value: 1970, Percentage: 0.19%
#
# ==================================================
#
# Column: patient.frequency_of_alcohol_consumption
#   Value: nan, Percentage: 57.58%
#   Value: 7, Percentage: 20.08%
#   Value: 0, Percentage: 10.80%
#   Value: 1, Percentage: 3.60%
#   Value: 2, Percentage: 2.08%
#   Value: 4, Percentage: 1.89%
#   Value: 6, Percentage: 1.52%
#   Value: 5, Percentage: 1.14%
#   Value: 3, Percentage: 1.14%
#   Value: 2.5, Percentage: 0.19%
#
# ==================================================
#
# Column: patient.amount_of_alcohol_consumption_per_day
#   Value: nan, Percentage: 58.14%
#   Value: 0, Percentage: 11.36%
#   Value: 1, Percentage: 7.20%
#   Value: 3, Percentage: 4.55%
#   Value: 2, Percentage: 4.17%
#   Value: 6, Percentage: 3.41%
#   Value: 4, Percentage: 2.46%
#   Value: 12, Percentage: 1.89%
#   Value: 5, Percentage: 1.70%
#   Value: 7, Percentage: 1.33%
#   Value: 10, Percentage: 0.76%
#   Value: 8, Percentage: 0.57%
#   Value: 1.7, Percentage: 0.38%
#   Value: 2.5, Percentage: 0.38%
#   Value: 3.5, Percentage: 0.38%
#   Value: 33, Percentage: 0.19%
#   Value: 24, Percentage: 0.19%
#   Value: 03, Percentage: 0.19%
#   Value: 15, Percentage: 0.19%
#   Value: 17, Percentage: 0.19%
#   Value: 16, Percentage: 0.19%
#   Value: .5, Percentage: 0.19%
#
# ==================================================
#
# Column: patient.hpv_status_by_p16_testing
#   Value: nan, Percentage: 78.22%
#   Value: Negative, Percentage: 14.02%
#   Value: Positive, Percentage: 7.77%
#
# ==================================================
#
# Column: patient.hpv_status_by_ish_testing
#   Value: nan, Percentage: 83.14%
#   Value: Negative, Percentage: 12.69%
#   Value: Positive, Percentage: 4.17%
#
# ==================================================
#
# Column: patient.egfr_amplication_status
#   Value: nan, Percentage: 94.89%
#   Value: Unamplified, Percentage: 3.03%
#   Value: Amplified, Percentage: 2.08%
#
# ==================================================

# %% [markdown]
# Note: a patient does not have age at diagnosis which is weird but not a big deal for now I guess. At this point the data is ready for processing

# %%
import pandas as pd

# Load the Excel file with endpoints
file_path = "/home/sorkwos/1b5f413e-a8d1-4d10-92eb-7c4ae739ed81/TCGA-CDR-SupplementalTableS1.xlsx"
df = pd.read_excel(file_path)

df_hnsc = df[df['type'].str.contains("HNSC", na=False)]

display_scrollable_dataframe(df_hnsc)
# Out:
# <table border="1" class="dataframe table table-striped table-bordered table-hover">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Unnamed: 0</th>
#       <th>bcr_patient_barcode</th>
#       <th>type</th>
#       <th>age_at_initial_pathologic_diagnosis</th>
#       <th>gender</th>
#       <th>race</th>
#       <th>ajcc_pathologic_tumor_stage</th>
#       <th>clinical_stage</th>
#       <th>histological_type</th>
#       <th>histological_grade</th>
#       <th>initial_pathologic_dx_year</th>
#       <th>menopause_status</th>
#       <th>birth_days_to</th>
#       <th>vital_status</th>
#       <th>tumor_status</th>
#       <th>last_contact_days_to</th>
#       <th>death_days_to</th>
#       <th>cause_of_death</th>
#       <th>new_tumor_event_type</th>
#       <th>new_tumor_event_site</th>
#       <th>new_tumor_event_site_other</th>
#       <th>new_tumor_event_dx_days_to</th>
#       <th>treatment_outcome_first_course</th>
#       <th>margin_status</th>
#       <th>residual_tumor</th>
#       <th>OS</th>
#       <th>OS.time</th>
#       <th>DSS</th>
#       <th>DSS.time</th>
#       <th>DFI</th>
#       <th>DFI.time</th>
#       <th>PFI</th>
#       <th>PFI.time</th>
#       <th>Redaction</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>
0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>1.0</td>
#       <td>389.0</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>3248</th>
#       <td>3249</td>
#       <td>TCGA-BA-5151</td>
#       <td>HNSC</td>
#       <td>72.0</td>
#       <td>MALE</td>
#       <td>WHITE</td>
#       <td>Stage IVA</td>
#       <td>Stage IVA</td>
#       <td>Head &amp; Neck Squamous Cell Carcinoma</td>
#       <td>G1</td>
#       <td>2010.0</td>
#       <td>[Not Available]</td>
#       <td>-26569.0</td>
#       <td>Alive</td>
#       <td>TUMOR FREE</td>
#       <td>722.0</td>
#       <td>NaN</td>
#       <td>[Not Available]</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>517.0</td>
#       <td>Complete Remission/Response</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>0.0</td>
#       <td>722.0</td>
#       <td>0.0</td>
#       <td>722.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>1.0</td>
#       <td>517.0</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>3249</th>
#       <td>3250</td>
#       <td>TCGA-BA-5152</td>
#       <td>HNSC</td>
#       <td>56.0</td>
#       <td>MALE</td>
#       <td>WHITE<

# %%
# Step 1: Select relevant columns from df_hnsc
df_hnsc_filtered = df_hnsc[['bcr_patient_barcode', 'PFI', 'PFI.time']]

# Step 2: Merge the two DataFrames based on the patient barcode
clinical_data_final_updated = clinical_data_final.merge(
    df_hnsc_filtered,
    left_on='patient.bcr_patient_barcode',
    right_on='bcr_patient_barcode',
    how='left'  # Use 'left' to keep all rows from clinical_data_final and add matches from df_hnsc
)

# Step 3: Drop the redundant 'bar_patient_barcode' column after merging
clinical_data_final_updated = clinical_data_final_updated.drop(columns=['bcr_patient_barcode'])

# Display the updated DataFrame
#display_scrollable_dataframe(clinical_data_final_updated)

clinical_data_yes = clinical_data_final_updated.drop(columns=['patient.bcr_patient_barcode','patient.bcr_patient_uuid'])

# %%
print(clinical_data_yes.iloc[7])
#numerical columns are: patient.days_to_birth, patient.tobacco_smoking_history, patient.year_of_tobacco_smoking_onset, patient.number_pack_years_smoked,
# Out:
# patient.histological_type                                            Head & Neck Squamous Cell Carcinoma
# patient.gender                                                                                    FEMALE
# patient.days_to_birth                                                                             -22299
# patient.race_list.race                                                                             WHITE
# patient.icd_o_3_site                                                                               C32.9
# patient.icd_o_3_histology                                                                         8070/3
# patient.icd_10                                                                                     C32.9
# patient.anatomic_neoplasm_subdivision                                                             Larynx
# patient.laterality                                                                                   NaN
# patient.tobacco_smoking_history                                                                        2
# patient.year_of_tobacco_smoking_onset                                                                NaN
# patient.number_pack_years_smoked                                                                     NaN
# patient.alcohol_history_documented                                                                    NO
# patient.other_dx                                                                                      No
# patient.stage_event.clinical_stage                                                              Stage II
# patient.stage_event.tnm_categories.clinical_categories.clinical_T                                     T2
# patient.stage_event.tnm_categories.clinical_categories.clinical_N                                     N0
# patient.stage_event.tnm_categories.clinical_categories.clinical_M                                     M0
# patient.ethnicity                                                                 NOT HISPANIC OR LATINO
# patient.stopped_smoking_year                                                                         NaN
# patient.frequency_of_alcohol_consumption                                                             NaN
# patient.amount_of_alcohol_consumption_per_day                                                        NaN
# patient.hpv_status_by_p16_testing                                                                    NaN
# patient.hpv_status_by_ish_testing                                                               Negative
# patient.egfr_amplication_status                                                                Amplified
# PFI                                                                                                  0.0
# PFI.time                                                                                          1483.0
# Name: 7, dtype: object

# %%
display_scrollable_dataframe(clinical_data_yes)
# Out:
# <table border="1" class="dataframe table table-striped table-bordered table-hover">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>patient.histological_type</th>
#       <th>patient.gender</th>
#       <th>patient.days_to_birth</th>
#       <th>patient.race_list.race</th>
#       <th>patient.icd_o_3_site</th>
#       <th>patient.icd_o_3_histology</th>
#       <th>patient.icd_10</th>
#       <th>patient.anatomic_neoplasm_subdivision</th>
#       <th>patient.laterality</th>
#       <th>patient.tobacco_smoking_history</th>
#       <th>patient.year_of_tobacco_smoking_onset</th>
#       <th>patient.number_pack_years_smoked</th>
#       <th>patient.alcohol_history_documented</th>
#       <th>patient.other_dx</th>
#       <th>patient.stage_event.clinical_stage</th>
#       <th>patient.stage_event.tnm_categories.clinical_categories.clinical_T</th>
#       <th>patient.stage_event.tnm_categories.clinical_categories.clinical_N</th>
#       <th>patient.stage_event.tnm_categories.clinical_categories.clinical_M</th>
#       <th>patient.ethnicity</th>
#       <th>patient.stopped_smoking_year</th>
#       <th>patient.frequency_of_alcohol_consumption</th>
#       <th>patient.amount_of_alcohol_consumption_per_day</th>
#       <th>patient.hpv_status_by_p16_testing</th>
#       <th>patient.hpv_status_by_ish_testing</th>
#       <th>patient.egfr_amplication_status</th>
#       <th>PFI</th>
#       <th>PFI.time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Head &amp; Neck Squamous Cell Carcinoma</td>
#       <td>MALE</td>
#       <td>-22836</td>
#       <td>WHITE</td>
#       <td>C32.9</td>
#       <td>8070/3</td>
#       <td>C32.9</td>
#       <td>Larynx</td>
#       <td>Midline</td>
#       <td>2</td>
#       <td>1959</td>
#       <td>50</td>
#       <td>NO</td>
#       <td>No</td>
#       <td>Stage IVA</td>
#       <td>T4a</td>
#       <td>N0</td>
#       <td>M0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>0.0</td>
#       <td>1971.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Head &amp; Neck Squamous Cell Carcinoma</td>
#       <td>MALE</td>
#       <td>-21659</td>
#       <td>WHITE</td>
#       <td>C02.9</td>
#       <td>8071/3</td>
#       <td>C02.9</td>
#       <td>Oral Tongue</td>
#       <td>Left</td>
#       <td>3</td>
#       <td>1973</td>
#       <td>39</td>
#       <td>NO</td>
#       <td>No</td>
#       <td>Stage IVA</td>
#       <td>T2</td>
#       <td>N2</td>
#       <td>M0</td>
#       <td>NOT HISPANIC OR LATINO</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>0.0</td>
#       <td>539.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Head &amp; Neck Squamous Cell Carcinoma</td>
#       <td>MALE</td>
#       <td>-19956</td>
#       <td>BLACK OR AFRICAN AMERICAN</td>
#       <td>C32.9</td>
#       <td>8070/3</td>
#       <td>C32.9</td>
#       <td>Larynx</td>
#       <td>Right</td>
#       <td>4</td>
#       <td>NaN</td>
#       <td>62</td>
#       <td>YES</td>
#       <td>No</td>
#       <td>Stage IVA</td>
#       <td>T2</td>
#       <td>N2c</td>
#       <td>M0</td>
#       <td>NOT HISPANIC OR LATINO</td>
#       <td>2010</td>
#       <td>0</td>
#       <td>0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>1.0</td>
#       <td>248.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Head &amp; Neck Squamous Cell Carcinoma</td>
#       <td>MALE</td>
#       <td>-23185</td>
#       <td>ASIAN</td>
#       <td>C06.9</td>
#       <td>8070/3</td>
#       <td>C06.9</td>
#       <td>Oral Tongue</td>
#       <td>Right</td>
#       <td>1</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>YES</td>
#       <td>No</td>
#       <td>Stage IVA</td>
#       <td>T2</td>
#       <td>N2c</td>
#       <td>M0</td>
#       <td>NOT HISPANIC OR LATINO</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>Positive</td>
#       <td>Negative</td>
#       <td>NaN</td>
#       <td>0.0</td>
#       <td>1168.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Head &amp; Neck Squamous Cell Carcinoma</td>
#       <td>MALE</td>
#       <td>-14133</td>
#       <td>WHITE</td>
#       <td>C09.9</td>
#       <td>8070/3</td>
#       <td>C09.9</td>
#       <td>Tonsil</td>
#       <td>Right</td>
#       <td>1</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>YES</td>
#       <td>No</td>
#       <td>Stage IVA</td>
#       <td>T1</td>
#       <td>N2c</td>
#       <td>M0</td>
#       <td>NOT HISPANIC OR LATINO</td>
#       <td>NaN</td>
#       <td>5</td>
#       <td>2.5</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>0.0</td>
#       <td>1521.0</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Head &amp; Neck Squamous Cell Carcinoma</td>
#       <td>FEMALE</td>
#       <td>-28250</td>
#       <td>WHITE</td>
#       <td>C02.9</td>
#       <td>8070/3</td>
#       <td>C02.9</td>
#       <td>Oral Tongue</td>
#       <td>Left</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NO</td>
#       <td>No</td>
#       <td>Stage IVA</td>
#       <td>T2</td>
#       <td>N2c</td>
#       <td>M0</td>
#       <td>NOT HISPANIC OR LATINO</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>0.0</td>
#       <td>144.0</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Head &amp; Neck Squamous Cell Carcinoma</td>
#       <td>MALE</td>
#       <td>-21443</td>
#       <td>WHITE</td>
#       <td>C32.9</td>
#       <td>8070/3</td>
#       <td>C32.9</td>
#       <td>Larynx</td>
#       <td>NaN</td>
#       <td>2</td>
#       <td>NaN</td>
#       <td>40</td>
#       <td>YES</td>
#       <td>No</td>
#       <td>Stage IVA</td>
#       <td>T3</td>
#       <td>N2b</td>
#       <td>M0</td>
#       <td>NOT HISPANIC OR LATINO</td>
#       <td>NaN</td>
#       <td>7</td>
#       <td>6</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>0.0</td>
#       <td>2016.0</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Head &amp; Neck Squamous Cell Carcinoma</td>
#       <td>FEMALE</td>
#       <td>-22299</td>
#       <td>WHITE</td>
#       <td>C32.9</td>
#       <td>8070/3</td>
#       <td>C32.9</td>
#       <td>Larynx</td>
#       <td>NaN</td>
#       <td>2</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NO</td>
#       <td>No</td>
#       <td>Stage II</td>
#       <td>T2</td>
#       <td>N0</td>
#       <td>M0</td>
#       <td>NOT HISPANIC OR LATINO</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>Negative</td>
#       <td>Amplified</td>
#       <td>0.0</td>
#       <td>1483.0</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>Head &amp; Neck Squamous Cell Carcinoma</td>
#       <td>MALE</td>
#       <td>-25020</td>
#       <td>BLACK OR AFRICAN AMERICAN</td>
#       <td>C32.9</td>
#       <td>8070/3</td>
#       <td>C32.9</td>
#       <td>Larynx</td>
#       <td>NaN</td>
#       <td>2</td>
#       <td>NaN</td>
#       <td>60</td>
#       <td>YES</td>
#       <td>No</td>
#       <td>Stage IVA</td>
#       <td>T4a</td>
#       <td>N2c</td>
#       <td>M0</td>
#       <td>NOT HISPANIC OR LATINO</td>
#       <td>NaN</td>
#       <td>7</td>
#       <td>10</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>0.0</td>
#       <td>187.0</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>Head &amp; Neck Squamous Cell Carcinoma</td>
#       <td>FEMALE</td>
#       <td>-24180</td>
#       <td>WHITE</td>
#       <td>C02.9</td>
#       <td>8070/3</td>
#       <td>C02.9</td>
#       <td>Oral Tongue</td>
#       <td>NaN</td>
#       <td>2</td>
#       <td>1948</td>
#       <td>75</td>
#       <td>NO</td>
#       <td>No</td>
#       <td>Stage IVA</td>
#       <td>T3</td>
#       <td>N2b</td>
#       <td>M0</td>
#       <td>NOT HISPANIC OR LATINO</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>1.0</td>
#       <td>65.0</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td

# %%
import pandas as pd
from sksurv.ensemble import RandomSurvivalForest
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import StandardScaler
import numpy as np
from imblearn.over_sampling import RandomOverSampler

# Convert string columns to numeric columns
clinical_data_test = clinical_data_yes.copy()  # Avoid modifying the original dataframe

# Define columns for specific treatments
num_cols = ['patient.days_to_birth', 'patient.tobacco_smoking_history', 'patient.year_of_tobacco_smoking_onset',
            'patient.number_pack_years_smoked', 'patient.stopped_smoking_year',
            'patient.frequency_of_alcohol_consumption', 'patient.amount_of_alcohol_consumption_per_day']

tobacco_alcohol_cols = [
    'patient.tobacco_smoking_history', 'patient.year_of_tobacco_smoking_onset',
    'patient.number_pack_years_smoked', 'patient.stopped_smoking_year',
    'patient.frequency_of_alcohol_consumption', 'patient.amount_of_alcohol_consumption_per_day'
]

days_to_birth_col = ['patient.days_to_birth']

# Convert all numerical columns to float and handle conversion errors
for col in tobacco_alcohol_cols + days_to_birth_col:
    clinical_data_test[col] = pd.to_numeric(clinical_data_test[col], errors='coerce')

# Replace NaNs in tobacco and alcohol-related columns with -1
for col in tobacco_alcohol_cols:
    clinical_data_test[col].fillna(-1, inplace=True)

# Replace NaNs in 'days_to_birth' with the mean
clinical_data_test['patient.days_to_birth'].fillna(clinical_data_test['patient.days_to_birth'].mean(), inplace=True)

# Replace NaNs in categorical columns with the string "missing"
categorical_cols = clinical_data_test.select_dtypes(include=['object']).columns
clinical_data_test[categorical_cols] = clinical_data_test[categorical_cols].fillna("missing")

# Extract time-to-event and event data
clinical_data_test['PFI.time'].fillna(clinical_data_test['PFI.time'].mean(), inplace=True)
time = clinical_data_test['PFI.time'].values.astype(float)
event = clinical_data_test['PFI'].values.astype(bool)

# Define the structured array for scikit-survival
survival_data = np.array([(e, t) for e, t in zip(event, time)], dtype=[('event', bool), ('time', float)])

# Select features
X = clinical_data_test[num_cols].values

# Scale numerical features
scaler = StandardScaler()
X = scaler.fit_transform(X)

# Initialize stratified k-fold cross-validation
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# Initialize empty list to store C-index scores for each fold
c_index_scores = []

# Cross-validation loop
for fold_idx, (train_index, test_index) in enumerate(skf.split(X, event)):
    # Split the data into training and test sets
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = survival_data[train_index], survival_data[test_index]

    # Extract the 'event' part for balancing
    event_labels = y_train['event'].astype(int)  # Convert to integer for compatibility with RandomOverSampler

    # Print training and test details before balancing
    n_samples_train_before = len(y_train)
    n_events_before = np.sum(event_labels)
    n_non_events_before = n_samples_train_before - n_events_before
    n_samples_test = len(y_test)
    n_events_test = np.sum(y_test['event'])
    n_non_events_test = n_samples_test - n_events_test
    print(f"Fold {fold_idx + 1} - Before Balancing: Training Samples: {n_samples_train_before} | Events: {n_events_before} | Non-Events: {n_non_events_before}")
    print(f"Fold {fold_idx + 1} - Test Samples: {n_samples_test} | Events: {n_events_test} | Non-Events: {n_non_events_test}")

    # Balance training set using RandomOverSampler (oversampling minority events)
    ros = RandomOverSampler(sampling_strategy='minority', random_state=42)
    X_train_balanced, event_labels_balanced = ros.fit_resample(X_train, event_labels)

    # Recreate the structured array for y_train_balanced using balanced labels and original time values
    y_train_balanced = np.array([(e, t) for e, t in zip(event_labels_balanced, y_train['time'][ros.sample_indices_])], 
                                dtype=[('event', bool), ('time', float)])

    # Print sample count and event details after oversampling
    n_samples_train_after = len(y_train_balanced)
    n_events_after = np.sum(y_train_balanced['event'])
    n_non_events_after = n_samples_train_after - n_events_after
    print(f"Fold {fold_idx + 1} - After Balancing: Training Samples: {n_samples_train_after} | Events: {n_events_after} | Non-Events: {n_non_events_after}")

    # Train the Random Survival Forest model
    rsf = RandomSurvivalForest(n_estimators=100, random_state=42)
    rsf.fit(X_train_balanced, y_train_balanced)

    # Evaluate on the test set (no balancing here)
    c_index = rsf.score(X_test, y_test)
    c_index_scores.append(c_index)

# Average C-index across folds
average_c_index = np.mean(c_index_scores)
print(f"Average Concordance index across folds: {average_c_index:.4f}")
# Out:
# Fold 1 - Before Balancing: Training Samples: 422 | Events: 158 | Non-Events: 264
# Fold 1 - Test Samples: 106 | Events: 40 | Non-Events: 66
# Fold 1 - After Balancing: Training Samples: 528 | Events: 264 | Non-Events: 264
# Fold 2 - Before Balancing: Training Samples: 422 | Events: 158 | Non-Events: 264
# Fold 2 - Test Samples: 106 | Events: 40 | Non-Events: 66
# Fold 2 - After Balancing: Training Samples: 528 | Events: 264 | Non-Events: 264
# Fold 3 - Before Balancing: Training Samples: 422 | Events: 158 | Non-Events: 264
# Fold 3 - Test Samples: 106 | Events: 40 | Non-Events: 66
# Fold 3 - After Balancing: Training Samples: 528 | Events: 264 | Non-Events: 264
# Fold 4 - Before Balancing: Training Samples: 423 | Events: 159 | Non-Events: 264
# Fold 4 - Test Samples: 105 | Events: 39 | Non-Events: 66
# Fold 4 - After Balancing: Training Samples: 528 | Events: 264 | Non-Events: 264
# Fold 5 - Before Balancing: Training Samples: 423 | Events: 159 | Non-Events: 264
# Fold 5 - Test Samples: 105 | Events: 39 | Non-Events: 66
# Fold 5 - After Balancing: Training Samples: 528 | Events: 264 | Non-Events: 264
# Average Concordance index across folds: 0.4594
